# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.describe(include='all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.665471     1.094918    NaN        NaN
# std       14.049960   NaN     6.098382     1.205493    NaN        NaN
# min       18.000000   NaN    16.000000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.300000     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.700000     2.000000    NaN        NaN
# max       64.000000   NaN    53.100000     5.000000    NaN        NaN
#
#             expenses
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
df.shape
# Out:
# (1338, 7)

# %%
df=df.drop_duplicates()

# %% [markdown]
# # Data Analysis

# %%
x_axis=['age','bmi','children','expenses']

for x in x_axis:
    fig,axes=plt.subplots(1,2,figsize=(18,4))
     # Left subplot: Distribution plot
    sns.histplot(df[x], kde=True, bins=30, ax=axes[0], color='skyblue')
    axes[0].set_title(f'Distribution of {x}', fontsize=14)
    
    # Right subplot: Boxplot
    sns.boxplot(x=df[x], ax=axes[1], color='lightgreen')
    axes[1].set_title(f'Boxplot of {x}', fontsize=14)
    
    plt.show()

# %% [markdown]
# ## handle categorical columns

# %%
df.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['sex']=df.sex.map({'female':0,'male':0})

# %%
df.head()
# Out:
#    age  sex   bmi  children smoker     region  expenses
# 0   19    0  27.9         0    yes  southwest  16884.92
# 1   18    0  33.8         1     no  southeast   1725.55
# 2   28    0  33.0         3     no  southeast   4449.46
# 3   33    0  22.7         0     no  northwest  21984.47
# 4   32    0  28.9         0     no  northwest   3866.86

# %%
df.smoker.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['smoker']=df.smoker.map({'yes':1,'no':0})

# %%
df.head()
# Out:
#    age  sex   bmi  children  smoker     region  expenses
# 0   19    0  27.9         0       1  southwest  16884.92
# 1   18    0  33.8         1       0  southeast   1725.55
# 2   28    0  33.0         3       0  southeast   4449.46
# 3   33    0  22.7         0       0  northwest  21984.47
# 4   32    0  28.9         0       0  northwest   3866.86

# %%
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df['region']=df.region.map({'southwest':1,'southeast':2,'northwest':3,'northeast':4})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   int64
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   int64
#  5   region    1337 non-null   int64
#  6   expenses  1337 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 83.6 KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
X=df.drop(['expenses'],axis=1)
y=df[['expenses']]

# %%
X.head()
# Out:
#    age  sex   bmi  children  smoker  region
# 0   19    0  27.9         0       1       1
# 1   18    0  33.8         1       0       2
# 2   28    0  33.0         3       0       2
# 3   33    0  22.7         0       0       3
# 4   32    0  28.9         0       0       3

# %%
y.head()
# Out:
#    expenses
# 0  16884.92
# 1   1725.55
# 2   4449.46
# 3  21984.47
# 4   3866.86

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (1069, 6)

# %%
X_test.shape
# Out:
# (268, 6)

# %% [markdown]
# ## ModelTraining

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    median_absolute_error,
    explained_variance_score
)

# R² Score (Coefficient of Determination)
r2 = r2_score(y_test, y_pred)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Mean Absolute Percentage Error (MAPE)
mape = mean_absolute_percentage_error(y_test, y_pred)

# Median Absolute Error
medae = median_absolute_error(y_test, y_pred)

# Explained Variance Score
evs = explained_variance_score(y_test, y_pred)

# Print all metrics nicely
print("📊 Regression Model Performance:")
print(f"R² Score: {r2:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}")
print(f"Median Absolute Error: {medae:.4f}")
print(f"Explained Variance Score: {evs:.4f}")
# Out:
# 📊 Regression Model Performance:
# R² Score: 0.8068
# Mean Absolute Error (MAE): 4183.6969
# Mean Squared Error (MSE): 35510170.4504
# Root Mean Squared Error (RMSE): 5959.0411
# Mean Absolute Percentage Error (MAPE): 0.4185
# Median Absolute Error: 2636.0874
# Explained Variance Score: 0.8078

# %%
score1
# Out:
# 0.8067537538208837

# %% [markdown]
# ## support Vector regressor

# %%
from sklearn.svm import SVR

# %%
svm=SVR()

# %%
svm.fit(X_train,y_train)
# Out:
# /home/kausik/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_pred1=svm.predict(X_test)

# %%
# ==========================
# 📈 Accuracy Metrics
# ==========================
r2_1 = r2_score(y_test, y_pred1)
mae_1 = mean_absolute_error(y_test, y_pred1)
mse_1 = mean_squared_error(y_test, y_pred1)
rmse_1 = np.sqrt(mse_1)
mape_1 = mean_absolute_percentage_error(y_test, y_pred1)
medae_1 = median_absolute_error(y_test, y_pred1)
evs_1 = explained_variance_score(y_test, y_pred1)

# ==========================
# 📊 Print Results
# ==========================
print("📊 SVM Model Performance (1):")
print(f"R² Score (1): {r2_1:.4f}")
print(f"Mean Absolute Error (MAE_1): {mae_1:.4f}")
print(f"Mean Squared Error (MSE_1): {mse_1:.4f}")
print(f"Root Mean Squared Error (RMSE_1): {rmse_1:.4f}")
print(f"Mean Absolute Percentage Error (MAPE_1): {mape_1:.4f}")
print(f"Median Absolute Error (1): {medae_1:.4f}")
print(f"Explained Variance Score (1): {evs_1:.4f}")
# Out:
# 📊 SVM Model Performance (1):
# R² Score (1): -0.1344
# Mean Absolute Error (MAE_1): 9249.7453
# Mean Squared Error (MSE_1): 208461506.0813
# Root Mean Squared Error (RMSE_1): 14438.1961
# Mean Absolute Percentage Error (MAPE_1): 1.0219
# Median Absolute Error (1): 4942.6545
# Explained Variance Score (1): 0.0039

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# /home/kausik/anaconda3/lib/python3.13/site-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred_rf=rf.predict(X_test)

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("📊 Random Forest Regression Results:")
print(f"MAE  : {mae_rf:.4f}")
print(f"MSE  : {mse_rf:.4f}")
print(f"RMSE : {rmse_rf:.4f}")
print(f"R²   : {r2_rf:.4f}")
# Out:
# 📊 Random Forest Regression Results:
# MAE  : 2567.5913
# MSE  : 21702291.1534
# RMSE : 4658.5718
# R²   : 0.8819

# %%
## final model is randomforestRegressor

# %%
data={
    'age':40,
    'sex':1,
    'bmi':40,
    'children':2,
    'smoker':1,
    'region':3
}

new_df=pd.DataFrame(data,index=[0])
new_df
# Out:
#    age  sex  bmi  children  smoker  region
# 0   40    1   40         2       1       3

# %%
pred=rf.predict(new_df)
pred[0]
# Out:
# np.float64(42283.24040000004)

# %%
import joblib
joblib.dump(rf,'random_forest_regressor')
# Out:
# ['random_forest_regressor']
